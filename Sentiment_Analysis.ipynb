# %%
# mount to Google drive
from google.colab import drive
drive.mount('/content/drive')

import os
os.chdir('/content/drive/My Drive/')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# install and import mlflow
import importlib

# !pip install mlflow --quiet

import os
import pandas as pd

import mlflow

# %%
# setting mlflow artefacts
# artefacts_temp_dir = 'artefacts_mlflow'
# if not os.path.exists(artefacts_temp_dir):
#     os.makedirs(artefacts_temp_dir)

mlflow.create_experiment('test')
# Out:
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# <ipython-input-48-5ec0c1211d08> in <module>()
#       4 #     os.makedirs(artefacts_temp_dir)
#       5
# ----> 6 mlflow.create_experiment('test')
#
# /usr/local/lib/python3.7/dist-packages/mlflow/tracking/fluent.py in create_experiment(name, artifact_location, tags)
#     949         Lifecycle_stage: active
#     950     """
# --> 951     return MlflowClient().create_experiment(name, artifact_location, tags)
#     952
#     953
#
# /usr/local/lib/python3.7/dist-packages/mlflow/tracking/client.py in create_experiment(self, name, artifact_location, tags)
#     505             Lifecycle_stage: active
#     506         """
# --> 507         return self._tracking_client.create_experiment(name, artifact_location, tags)
#     508
#     509     def delete_experiment(self, experiment_id: str) -> None:
#
# /usr/local/lib/python3.7/dist-packages/mlflow/tracking/_tracking_service/client.py in create_experiment(self, name, artifact_location, tags)
#     183             name=name,
#     184             artifact_location=artifact_location,
# --> 185             tags=[ExperimentTag(key, value) for (key, value) in tags.items()] if tags else [],
#     186         )
#     187
#
# /usr/local/lib/python3.7/dist-packages/mlflow/store/tracking/rest_store.py in create_experiment(self, name, artifact_location, tags)
#      97             CreateExperiment(name=name, artifact_location=artifact_location, tags=tag_protos)
#      98         )
# ---> 99         response_proto = self._call_endpoint(CreateExperiment, req_body)
#     100         return response_proto.experiment_id
#     101
#
# /usr/local/lib/python3.7/dist-packages/mlflow/store/tracking/rest_store.py in _call_endpoint(self, api, json_body)
#      54         endpoint, method = _METHOD_TO_INFO[api]
#      55         response_proto = api.Response()
# ---> 56         return call_endpoint(self.get_host_creds(), endpoint, method, json_body, response_proto)
#      57
#      58     def list_experiments(
#
# /usr/local/lib/python3.7/dist-packages/mlflow/utils/rest_utils.py in call_endpoint(host_creds, endpoint, method, json_body, response_proto)
#     238             host_creds=host_creds, endpoint=endpoint, method=method, json=json_body
#     239         )
# --> 240     response = verify_rest_response(response, endpoint)
#     241     js_dict = json.loads(response.text)
#     242     parse_dict(js_dict=js_dict, message=response_proto)
#
# /usr/local/lib/python3.7/dist-packages/mlflow/utils/rest_utils.py in verify_rest_response(response, endpoint)
#     173                 response.status_code,
#     174             )
# --> 175             raise MlflowException("%s. Response body: '%s'" % (base_msg, response.text))
#     176
#     177     # Skip validation for endpoints (e.g. DBFS file-download API) which may return a non-JSON
#
# MlflowException: API request to endpoint /api/2.0/mlflow/experiments/create failed with error code 401 != 200. Response body: '<html>
# <head>
# <meta http-equiv="Content-Type" content="text/html;charset=utf-8"/>
# <title>Error 401 Unauthorized</title>
# </head>
# <body><h2>HTTP ERROR 401</h2>
# <p>Problem accessing /api/2.0/mlflow/experiments/create. Reason:
# <pre>    Unauthorized</pre></p>
# </body>
# </html>
# '
